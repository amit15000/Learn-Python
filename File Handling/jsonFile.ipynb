# %%
import json

data = {
    "name": "Amit",
    "age": 25,
    "skills": ["Python", "AI"]
}

with open("data.json", "w") as f:
    json.dump(data, f)

# %%
with open("data.json") as f:
    data = json.load(f)
    print(data)
# Out:
# {'name': 'Amit', 'age': 25, 'skills': ['Python', 'AI']}

# %%
# Code to dumb json to a file

import json

with open("amit.txt") as rf:
    with open("data.json") as wf:
        data = json.dump(rf,wf)

    print(data)
    c
